# %%
# Imports and preparing the dataset

import thinkstats2
import thinkplot


import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import scipy

# %%
# Setting the default style of the plots
sns.set_style('whitegrid')
sns.set_palette('Set2')

# My custom color palette
my_palette = ["#7A92FF", "#FF7AEF", "#B77AFF", "#A9FF7A", "#FFB27A", "#FF7A7A",
             "#7AFEFF", "#D57AFF", "#FFDF7A", "#D3FF7A"]

# Importing the 4 datasets
data_2015 = pd.read_csv("C:/Users/Deependra/Documents/Term Project/2015.csv")
data_2016 = pd.read_csv("C:/Users/Deependra/Documents/Term Project/2016.csv")
data_2017 = pd.read_csv("C:/Users/Deependra/Documents/Term Project/2017.csv")
data_2018 = pd.read_csv("C:/Users/Deependra/Documents/Term Project/2018.csv")

# %%
## Preparing the data to merge the table. Tables have different columns,so selecting only the onew we need.
data_2015.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
data_2015 = data_2015 [['Country', 'Happiness Rank', 'Happiness Score',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Generosity', 'Trust (Government Corruption)']]

# %%
data_2016.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Lower Confidence Interval', 'Upper Confidence Interval',
#        'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
#        'Freedom', 'Trust (Government Corruption)', 'Generosity',
#        'Dystopia Residual'],
#       dtype='object')

# %%
data_2016 = data_2016 [['Country', 'Happiness Rank', 'Happiness Score',
       'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)',
       'Freedom', 'Generosity', 'Trust (Government Corruption)']]

# %%
data_2017.columns
# Out:
# Index(['Country', 'Happiness.Rank', 'Happiness.Score', 'Whisker.high',
#        'Whisker.low', 'Economy..GDP.per.Capita.', 'Family',
#        'Health..Life.Expectancy.', 'Freedom', 'Generosity',
#        'Trust..Government.Corruption.', 'Dystopia.Residual'],
#       dtype='object')

# %%
data_2017 = data_2017 [['Country', 'Happiness.Rank', 'Happiness.Score', 
       'Economy..GDP.per.Capita.', 'Family',
       'Health..Life.Expectancy.', 'Freedom', 'Generosity',
       'Trust..Government.Corruption.',
       ]]

# %%
data_2018.columns
# Out:
# Index(['Overall rank', 'Country or region', 'Score', 'GDP per capita',
#        'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption'],
#       dtype='object')

# %%
data_2018 = data_2018 [['Overall rank', 'Country or region', 'Score', 'GDP per capita',
       'Social support', 'Healthy life expectancy',
       'Freedom to make life choices', 'Generosity',
       'Perceptions of corruption']]

# %%
# Renaming the columns to have same columns names across the tables.
new_names = ['Country', 'Happiness_Rank', 'Happiness_Score','Economy_GDP', 'Family', 'Life_Expectancy', 
             'Freedom', 'Generosity', 'Trust_Corruption']

# %%
data_2015.columns = new_names
data_2016.columns = new_names
data_2017.columns = new_names
data_2018.columns = new_names

# %%
# Adding a new column as the year of the survey
data_2015['Year']= 2015
data_2016 ['Year'] = 2016
data_2017['Year'] = 2017
data_2018['Year'] = 2018

# %%
# Merging the data together
merged_data = pd.concat([data_2015, data_2016, data_2017, data_2018], axis =0)
merged_data.head(3)
# Out:
#        Country Happiness_Rank  Happiness_Score  Economy_GDP   Family  \
# 0  Switzerland              1            7.587      1.39651  1.34951
# 1      Iceland              2            7.561      1.30232  1.40223
# 2      Denmark              3            7.527      1.32548  1.36058
#
#    Life_Expectancy  Freedom  Generosity  Trust_Corruption  Year
# 0          0.94143  0.66557     0.29678           0.41978  2015
# 1          0.94784  0.62877     0.43630           0.14145  2015
# 2          0.87464  0.64938     0.34139           0.48357  2015

# %%
merged_data.describe()
# Out:
#        Happiness_Score  Economy_GDP      Family  Life_Expectancy     Freedom  \
# count       626.000000   626.000000  626.000000       626.000000  626.000000
# mean          5.372021     0.918764    1.045891         0.584299    0.415706
# std           1.131774     0.409808    0.328946         0.241948    0.154943
# min           2.693000     0.000000    0.000000         0.000000    0.000000
# 25%           4.497750     0.606755    0.847945         0.404142    0.310500
# 50%           5.307000     0.983705    1.081274         0.632553    0.434635
# 75%           6.187250     1.239502    1.283387         0.772957    0.538998
# max           7.632000     2.096000    1.644000         1.030000    0.724000
#
#        Generosity  Trust_Corruption         Year
# count  626.000000        625.000000   626.000000
# mean     0.226981          0.129138  2016.493610
# std      0.126854          0.108202     1.120339
# min      0.000000          0.000000  2015.000000
# ...

# %%
# We have one missing value in Trust(Corruption)
#Dropping the missing value
merged_data.dropna(axis=0, inplace = True)

# %%
#Plotting histograms of the variables.
hist = merged_data.hist(bins = 15)
hist = data_2015.hist(bins = 10)

# %%
hist = data_2016.hist(bins = 10)

# %%
hist = data_2017.hist(bins = 10)

# %%
hist = data_2018.hist(bins = 10)

# %%
new = merged_data.Economy_GDP
hist = new.hist(bins = 10)

# %%
# Histograms by grouping the variable year.

merged_data.hist(by = 'Year', column =  'Life_Expectancy')
# Out:
# array([[<AxesSubplot:title={'center':'2015'}>,
#         <AxesSubplot:title={'center':'2016'}>],
#        [<AxesSubplot:title={'center':'2017'}>,
#         <AxesSubplot:title={'center':'2018'}>]], dtype=object)

# %%
#summary statistics
merged_data.groupby(by = 'Year')['Happiness_Score'].describe()
# Out:
#       count      mean       std    min     25%     50%      75%    max
# Year
# 2015  158.0  5.375734  1.145010  2.839  4.5260  5.2325  6.24375  7.587
# 2016  157.0  5.382185  1.141674  2.905  4.4040  5.3140  6.26900  7.526
# 2017  155.0  5.354019  1.131230  2.693  4.5055  5.2790  6.10150  7.537
# 2018  155.0  5.366897  1.117433  2.905  4.4515  5.3580  6.15400  7.632

# %%
merged_data.groupby(by = 'Year')['Economy_GDP'].describe()
# Out:
#       count      mean       std  min       25%       50%       75%       max
# Year
# 2015  158.0  0.846137  0.403121  0.0  0.545808  0.910245  1.158448  1.690420
# 2016  157.0  0.953880  0.412595  0.0  0.670240  1.027800  1.279640  1.824270
# 2017  155.0  0.984718  0.420793  0.0  0.663371  1.064578  1.318027  1.870766
# 2018  155.0  0.883677  0.380942  0.0  0.612500  0.940000  1.192500  1.649000

# %%
merged_data.groupby(by = 'Year')['Family'].describe()
# Out:
#       count      mean       std  min       25%       50%       75%       max
# Year
# 2015  158.0  0.991046  0.272369  0.0  0.856823  1.029510  1.214405  1.402230
# 2016  157.0  0.793621  0.266706  0.0  0.641840  0.841420  1.021520  1.183260
# 2017  155.0  1.188898  0.287263  0.0  1.042635  1.253918  1.414316  1.610574
# 2018  155.0  1.216058  0.301286  0.0  1.075500  1.258000  1.464000  1.644000

# %%
merged_data.groupby(by = 'Year')['Life_Expectancy'].describe()
# Out:
#       count      mean       std  min       25%       50%       75%       max
# Year
# 2015  158.0  0.630259  0.247078  0.0  0.439185  0.696705  0.811013  1.025250
# 2016  157.0  0.557619  0.229349  0.0  0.382910  0.596590  0.729930  0.952770
# 2017  155.0  0.551341  0.237073  0.0  0.369866  0.606042  0.723008  0.949492
# 2018  155.0  0.596877  0.248312  0.0  0.420500  0.643000  0.778500  1.030000

# %%
#Lets see how the impact of variables has been over the years.
# Grouping the data by years and getting the average of the factors.
grouped = merged_data.groupby(by = 'Year')[['Economy_GDP', 'Family', 'Life_Expectancy', 
             'Freedom', 'Generosity', 'Trust_Corruption']].mean().reset_index()

# %%
# Reconstructing the dataframe using melt() function.
grouped = pd.melt(frame = grouped, id_vars = 'Year', value_vars = ['Economy_GDP', 'Family',
                                                                   'Life_Expectancy', 'Freedom', 'Generosity',
                                                                   'Trust_Corruption'], var_name = 'Factors', 
                  value_name = 'Avg_Value')

# %%
#Plotting the differences in factors.
plt.figure(figsize = (16, 9))

ax = sns.barplot(x = grouped[grouped['Factors'] != 'Score']['Factors'], y = grouped['Avg_Value'], 
            palette = my_palette[1:], hue = grouped['Year'])

plt.title("Impact of variables over years", fontsize = 25)
plt.xlabel("Factors", fontsize = 20)
plt.ylabel("Average Score", fontsize = 20)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.legend(fontsize = 15)

ax.set_xticklabels(['Econmy_GDP','Family', 'Life_Expectancy', 'Freedom', 'Generosity', 'Trust_Corruption']);

# %%
#Top two happiest countries. PMF
Happiest = merged_data[merged_data.Happiness_Rank == 1]
Second_Happiest = merged_data[merged_data.Happiness_Rank == 2]

# %%
pmf = thinkstats2.Pmf(Happiest.Happiness_Score)
pmf
# Out:
# Pmf({7.526: 0.3333333333333333, 7.587000000000001: 0.3333333333333333, 7.537000179290769: 0.3333333333333333})

# %%
pmf = thinkstats2.Pmf(Second_Happiest.Happiness_Score)
pmf
# Out:
# Pmf({7.561: 0.3333333333333333, 7.52199983596802: 0.3333333333333333, 7.5089999999999995: 0.3333333333333333})

# %%
#CDF
def EvalCdf(sample, x):
    count = 0.0
    for value in sample:
        if value <= x:
            count += 1

    prob = count / len(sample)
    return prob

# %%
cdf = thinkstats2.Cdf(Happiest.Happiness_Score, label='Score')
thinkplot.Cdf(cdf)
# Out:
# {'xscale': 'linear', 'yscale': 'linear'}

# %%
cdf = thinkstats2.Cdf(Happiest.Economy_GDP, label='GDP')
thinkplot.Cdf(cdf)
# Out:
# {'xscale': 'linear', 'yscale': 'linear'}

# %%
Happiest_cdf = thinkstats2.Cdf(Happiest.Economy_GDP, label='Happiest')
Second_cdf = thinkstats2.Cdf(Second_Happiest.Economy_GDP, label='Second_Happiest')

thinkplot.PrePlot(2)
thinkplot.Cdfs([Happiest_cdf, Second_cdf])
thinkplot.Config(xlabel='GDP ', ylabel='CDF')

# %%
#normal probability curve for GDP

mean, var = thinkstats2.TrimmedMeanVar(merged_data.Economy_GDP, p=0.01)
std = np.sqrt(var)

xs = [-4, 4]
fxs, fys = thinkstats2.FitLine(xs, mean, std)
thinkplot.Plot(fxs, fys, linewidth=4, color='0.8')

xs, ys = thinkstats2.NormalProbability(merged_data.Economy_GDP)
thinkplot.Plot(xs, ys, label='all live')

thinkplot.Config(title='Normal probability plot',
                 xlabel='Standard deviations from mean',
                 ylabel='GDP')

# %%
#Distribution of Happiness Score over time
plt.figure(figsize = (16, 9))

sns.distplot(a = merged_data['Happiness_Score'], bins = 20, kde = True, color = "#A9FF7A")
plt.xlabel('Happiness Score', fontsize = 20)
plt.title('Distribution of Average Happiness Score over Time -', fontsize = 25)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15)
plt.xlim((1.5, 8.9));
# Out:
# C:\Users\Deependra\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#Scatter plot of GDP and happiness score.
GDP, Score = merged_data.Economy_GDP, merged_data.Happiness_Score

thinkplot.Scatter(GDP, Score, alpha=1)
thinkplot.Config(xlabel='GDP ',
                 ylabel='Score',
                 legend=False)

# %%
GDP, Score = merged_data.Economy_GDP, merged_data.Happiness_Score

thinkplot.Scatter(GDP, Score, alpha=0.1, s=10)
thinkplot.Config(xlabel='GDP ',
                 ylabel='Score',
                 legend=False)

# %%
#Plotting percentiles of GDP and Happiness Score
cleaned = merged_data.dropna(subset=['Economy_GDP', 'Happiness_Score'])

bins = np.arange(0.00,1.75,0.25)
indices = np.digitize(cleaned.Economy_GDP, bins)
groups = cleaned.groupby(indices)
    
mean_GDP = [group.Economy_GDP.mean() for i, group in groups][1:-1]
cdfs = [thinkstats2.Cdf(group.Happiness_Score) for i, group in groups][1:-1]


for percent in [75, 50, 25]:
    Score_percentiles = [cdf.Percentile(percent) for cdf in cdfs]
    label = '%dth' % percent
    thinkplot.Plot(mean_GDP, Score_percentiles, label=label)
    
thinkplot.Config(xlabel='GDP',
                 ylabel='Score',
                  xlim =[0.2, 1.6],
                 legend=True)

# %%
#covariance

def Cov(xs, ys, meanx=None, meany=None):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    if meanx is None:
        meanx = np.mean(xs)
    if meany is None:
        meany = np.mean(ys)

    cov = np.dot(xs-meanx, ys-meany) / len(xs)
    return cov


Cov(GDP, Score)
# Out:
# 0.363103193621415

# %%
# Computing the Correlation Matrix
merged_data.corr()
# Out:
#                   Happiness_Score  Economy_GDP    Family  Life_Expectancy  \
# Happiness_Score          1.000000     0.789069  0.636423         0.754864
# Economy_GDP              0.789069     1.000000  0.574794         0.805913
# Family                   0.636423     0.574794  1.000000         0.516584
# Life_Expectancy          0.754864     0.805913  0.516584         1.000000
# Freedom                  0.552863     0.338151  0.440076         0.359678
# Generosity               0.154154    -0.003760 -0.004386         0.057510
# Trust_Corruption         0.404013     0.308169  0.135804         0.270141
# Year                    -0.005411     0.040049  0.363028        -0.049829
#
#                    Freedom  Generosity  Trust_Corruption      Year
# Happiness_Score   0.552863    0.154154          0.404013 -0.005411
# Economy_GDP       0.338151   -0.003760          0.308169  0.040049
# Family            0.440076   -0.004386          0.135804  0.363028
# ...

# %%
#Plotting the correlation matrix

corr = merged_data.corr()

# Generate a mask for the upper triangle
mask = np.triu(np.ones_like(corr, dtype=np.bool))

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(16, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(-0.10, 0.3, as_cmap=True, s = 10, l = 45, n = 5)

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask, cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

plt.title('Factors Influencing Happiness', fontsize = 25)
plt.xticks(fontsize = 15)
plt.yticks(fontsize = 15);

# %%
#Pearson's correlation
def Corr(xs, ys):
    xs = np.asarray(xs)
    ys = np.asarray(ys)

    meanx, varx = thinkstats2.MeanVar(xs)
    meany, vary = thinkstats2.MeanVar(ys)

    corr = Cov(xs, ys, meanx, meany) / np.sqrt(varx * vary)
    return corr

Corr(GDP, Score)
# Out:
# 0.7890689134173731

# %%
#Spearman's rank correlation between GDP and Happiness Score.
def SpearmanCorr(xs, ys):
    xranks = pd.Series(xs).rank()
    yranks = pd.Series(ys).rank()
    return Corr(xranks, yranks)

# %%
SpearmanCorr(GDP, Score)
# Out:
# 0.8038422126930368

# %%
#Hypothesis Testing.

class HypothesisTest(object):

    def __init__(self, data):
        self.data = data
        self.MakeModel()
        self.actual = self.TestStatistic(data)

    def PValue(self, iters=1000):
        self.test_stats = [self.TestStatistic(self.RunModel()) 
                           for _ in range(iters)]

        count = sum(1 for x in self.test_stats if x >= self.actual)
        return count / iters

    def TestStatistic(self, data):
        raise UnimplementedMethodException()

    def MakeModel(self):
        pass

    def RunModel(self):
        raise UnimplementedMethodException()

# %%
class DiffMeansPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = abs(group1.mean() - group2.mean())
        return test_stat

    def MakeModel(self):
        group1, group2 = self.data
        self.n, self.m = len(group1), len(group2)
        self.pool = np.hstack((group1, group2))

    def RunModel(self):
        np.random.shuffle(self.pool)
        data = self.pool[:self.n], self.pool[self.n:]
        return data

# %%
Happiest = merged_data[merged_data.Happiness_Rank == 1]
Second_Happiest = merged_data[merged_data.Happiness_Rank == 2]

data = Happiest.Economy_GDP.values, Second_Happiest.Economy_GDP.values

ht = DiffMeansPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.595

# %%
ht.PlotCdf()
thinkplot.Config(xlabel='test statistic',
                   ylabel='CDF')

# %%
class DiffStdPermute(DiffMeansPermute):

    def TestStatistic(self, data):
        group1, group2 = data
        test_stat = group1.std() - group2.std()
        return test_stat

# %%
ht = DiffStdPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.675

# %%
class CorrelationPermute(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        xs, ys = data
        test_stat = abs(thinkstats2.Corr(xs, ys))
        return test_stat

    def RunModel(self):
        xs, ys = self.data
        xs = np.random.permutation(xs)
        return xs, ys

# %%
ht = CorrelationPermute(data)
pvalue = ht.PValue()
pvalue
# Out:
# 0.661

# %%
#Hypothesis testing with slopes.

GDP = Happiest.Economy_GDP
Score = Second_Happiest.Happiness_Score

class SlopeTest(thinkstats2.HypothesisTest):

    def TestStatistic(self, data):
        GDP, Score = data
        _, slope = thinkstats2.LeastSquares(GDP, Score)
        return slope

    def MakeModel(self):
        _, weights = self.data
        self.ybar = Score.mean()
        self.res = Score - self.ybar

    def RunModel(self):
        GDP, _ = self.data
        Score = self.ybar + np.random.permutation(self.res)
        return GDP, Score

# %%
ht = SlopeTest((GDP, Score))
pvalue = ht.PValue()
pvalue
# Out:
# 0.677

# %%
#Simple Regression
import statsmodels.formula.api as smf

formula = 'Happiness_Score ~ Economy_GDP'
results = smf.ols(formula, data= merged_data).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Happiness_Score   R-squared:                       0.623
# Model:                            OLS   Adj. R-squared:                  0.622
# Method:                 Least Squares   F-statistic:                     1028.
# Date:                Sat, 05 Jun 2021   Prob (F-statistic):          5.89e-134
# Time:                        11:35:06   Log-Likelihood:                -658.89
# No. Observations:                 625   AIC:                             1322.
# Df Residuals:                     623   BIC:                             1331.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                   coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------
# Intercept       3.3609      0.069     49.022      0.000       3.226       3.495
# ...

# %%
#Multiple Regression.
formula = 'Happiness_Score ~ Economy_GDP + Family + Life_Expectancy + Freedom + Generosity + Trust_Corruption'
results = smf.ols(formula, data=merged_data).fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Happiness_Score   R-squared:                       0.765
# Model:                            OLS   Adj. R-squared:                  0.762
# Method:                 Least Squares   F-statistic:                     334.4
# Date:                Sat, 05 Jun 2021   Prob (F-statistic):          2.40e-190
# Time:                        11:37:51   Log-Likelihood:                -511.51
# No. Observations:                 625   AIC:                             1037.
# Df Residuals:                     618   BIC:                             1068.
# Df Model:                           6
# Covariance Type:            nonrobust
# ...
#                        coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# ...
